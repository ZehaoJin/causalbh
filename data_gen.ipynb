# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import seaborn as sns

# %%
df_full = pd.read_csv('SMBH_Data_03_15_24v2.csv',header=1)
df_full['D_L']=np.log10(df_full['D_L'])

df_ell=df_full[(df_full['ETG']==1)&(df_full['Disk']==0)]

df_len=df_full[(df_full['ETG']==1)&(df_full['Disk']==1)]

df_spr=df_full[(df_full['ETG']==0)&(df_full['Disk']==1)]


len(df_ell),len(df_len),len(df_spr),len(df_full)
# Out:
# (45, 50, 49, 145)

# %%
# show all columns in df_full, without truncation
for col in df_full.columns:
    print(col)
# Out:
# ID
# Galaxy
# ra
# dec
# RA_deg
# DEC_deg
# Morphology
# Type
# ETG
# Leda Type
# T-type
# T-type_std
# Arm Class
# Bar
# Disk
# Ring
# Core
# Multiple
# Compactness
# AGN
# Pseudobulge
# BCG
# cD
# M_BH
# M_BH_std_+
# M_BH_std_-
# M_BH_std_sym
# M*_sph
# M*_sph_std
# M*_disk
# M*_disk_std
# M*_gal
# M*_gal_std
# B/T
# B/T_std
# log_B/T
# log_B/T_std
# D/T
# D/T_std
# log_D/T
# log_D/T_std
# m_#_of_arms
# phi
# phi_std
# tan_phi
# tan_phi_std
# sigma0
# sigma0_std
# log_sigma0
# log_sigma0_std
# v_max
# v_max_std
# log_v_max
# log_v_max_std
# M_DM
# M_DM_std
# M_BH/M*_sph
# M_BH/M*_sph_std
# log_M_BH/M*_sph
# log_M_BH/M*_sph_std
# M_BH/M*_disk
# M_BH/M*_disk_std
# log_M_BH/M*_disk
# log_M_BH/M*_disk_std
# M_BH/M*_gal
# M_BH/M*_gal_std
# log_M_BH/M*_gal
# log_M_BH/M*_gal_std
# R_e_sph_maj
# R_e_sph_maj_std
# log_R_e_sph_maj
# log_R_e_sph_maj_std
# R_e_sph_eq_kpc
# R_e_sph_eq_kpc_std
# log_R_e_sph_eq_kpc
# log_R_e_sph_eq_kpc_std
# n_sph_maj
# n_sph_maj_std
# log_n_sph_maj
# log_n_sph_maj_std
# n_sph_eq
# n_sph_eq_std
# log_n_sph_eq
# log_n_sph_eq_std
# log(I_e,sph,maj/M_Sun/pc^2)
# log(I_e,sph,maj/M_Sun/pc^2)_std
# log(I_e,sph,eq/M_Sun/pc^2)
# log(I_e,sph,eq/M_Sun/pc^2)_std
# Concentration_Index
# Concentration_Index_std
# avg_Rho_1kpc_Exact_All
# avg_Rho_1kpc_Exact_All_std
# r1_density_approx
# r1_density_approx_std
# log10(R10_kpc)
# log10(R10_kpc)_std
# logRho_R10_approx
# logRho_R10_approx_std
# log_rho10_Exact
# log_rho10_Exact_std
# log10(R90_kpc)
# log10(R90_kpc)_std
# logRho_R90_approx
# logRho_R90_approx_std
# log_rho_90_Exact_all
# log_rho_90_Exact_all_std
# Rho_re_spatial
# Rho_re_spatial_std
# SR_pc_All
# SR_pc_All_std
# Rho_SR_pc_All
# Rho_SR_pc_All_std
# CR_def1_approx_new
# CR_def1_approx_new_std
# Rho_cr_def1_approx_new
# Rho_cr_def1_approx_new_std
# CR_def2_approx_new
# CR_def2_approx_new_std
# mean
# stdev
# Rho_CR_def2_approx_new
# Rho_CR_def2_approx_new_std
# mean.1
# stdev.1
# Sr(pc)_2_using_Falserm_drho
# Sr(pc)_2_using_Falserm_drho_std
# Log_Approx_Avg_density_10pc
# Log_Approx_Avg_density_10pc_std
# Rho_e_Exact_new
# Rho_e_Exact_new_std
# log_Rho_e_Exact_new
# log_Rho_e_Exact_new_std
# logRho_e_approx_New
# logRho_e_approx_New_std
# Rsoi_pc_new
# Rsoi_pc_new_std
# logRho_soi_approx_new
# logRho_soi_approx_new_std
# Rho_soi_exact_new
# Rho_soi_exact_new_std
# log_Rho_soi_exact_new
# log_Rho_soi_exact_new_std
# Rb_maj
# Rb_maj_std
# Rb_maj_kpc
# Rb_maj_kpc_std
# Rb_eq_kpc
# Rb_eq_kpc_std
# Avg_Rho_Re_Exact_all
# Avg_Rho_Re_Exact_all_std
# Avg_Rho_soi_exact_all
# Avg_Rho_soi_exact_all_std
# Avg_Rho_re_Exact_all
# Avg_Rho_re_Exact_all_std
# Rho_re_Exact_all
# Rho_re_Exact_all_std
# r_soi_2BH_approx
# r_soi_2BH_approx_std
# Rho_r_soi_2BH_approx
# Rho_r_soi_2BH_approx_std
# Log_Avg_Rho_10kpc_approx
# Log_Avg_Rho_10kpc_approx_std
# Log_Avg_Rho_10kpc_exact_final
# Log_Avg_Rho_10kpc_exact_final_std
# Log_Avg_Rho_100pc_approx
# Log_Avg_Rho_100pc_approx_std
# Log_Avg_Rho_5kpc_approx
# Log_Avg_Rho_5kpc_approx_std
# Log_Avg_rho_5kpc_exact_all
# Log_Avg_rho_5kpc_exact_all_std
# brief
# brief_std
# ube
# bve
# mg2
# mg2_std
# dc
# dc_std
# ubtc
# ubtc_std
# bvtc
# bvtc_std
# bri25
# m21c
# m21c_std
# hic
# hic_std
# mabs
# mabs_std
# blum
# blum_std
# logblum
# logblum_std
# logSigma0sph
# logSigma0sph_std
# LogSigma0
# LogSigma0_std
# R10
# R10_std
# logR10
# logR10_std
# logR10phi
# logR10phi_std
# Rh
# Rh_std
# logRh
# logRh_std
# logRhphi
# logRhphi_std
# logHalo
# logHalo_std
# B-V
# B-V_std
# V-[3.6]
# V-[3.6]_std
# CFUV
# CFUV_std
# CNUV
# CNUV_std
# GJC23 Type
# GJC23 Dust
# GJC23W1-W2
# GJC23W1-W2_std
# GJC23W2-W3
# GJC23W2-W3_std
# GJC23log(M*,gal/M_sun)
# GJC23log(M*,gal/M_sun)_std
# GJC23SFR
# GJC23SFR_std
# GJC23log(SFR)
# GJC23log(SFR)_std
# GJC23log(sSFR)
# GJC23log(sSFR)_std
# log<Sigma>_e
# log<Sigma>_e_std
# log<Sigma>_h
# log<Sigma>_h_std
# logRemajphi
# logRemajphi_std
# logReeqphi
# logReeqphi_std
# D_L
# D_L_std
# v
# v_std
# z
# z_std
# vol-mag-flag

# %%
test_keys=['Galaxy','M_BH','M_BH_std_sym', 'log_sigma0','log_sigma0_std','log_R_e_sph_eq_kpc','log_R_e_sph_eq_kpc_std',
           'log<Sigma>_e','log<Sigma>_e_std','GJC23log(M*,gal/M_sun)','GJC23log(M*,gal/M_sun)_std','GJC23log(sSFR)','GJC23log(sSFR)_std',
           'GJC23W2-W3','GJC23W2-W3_std']
df_ell=df_ell[test_keys]
df_len=df_len[test_keys]
df_spr=df_spr[test_keys]

df_test=df_ell[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_std_withname.csv',index=False)
# drop the galaxy name
df_test=df_ell[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_std.csv',index=False)

df_test=df_len[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len_std_withname.csv',index=False)
# drop the galaxy name
df_test=df_len[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len_std.csv',index=False)

df_test=df_spr[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr_std_withname.csv',index=False)
# drop the galaxy name
df_test=df_spr[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr_std.csv',index=False)
# Out:
# 35
# 35
# 38
# 38
# 28
# 28

# %%
test_keys=['Galaxy','M_BH', 'log_sigma0','log_R_e_sph_eq_kpc','log<Sigma>_e','GJC23log(M*,gal/M_sun)','GJC23log(sSFR)'
           ,'GJC23W2-W3']
df_test=df_ell[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_withname.csv',index=False)
# drop the galaxy name
df_test=df_ell[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell.csv',index=False)

df_test=df_len[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len_withname.csv',index=False)
# drop the galaxy name
df_test=df_len[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len.csv',index=False)

df_test=df_spr[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr_withname.csv',index=False)
# drop the galaxy name
df_test=df_spr[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr.csv',index=False)
# Out:
# 35
# 35
# 38
# 38
# 28
# 28

# %%
test_keys=['Galaxy','M_BH', 'log_sigma0','log_R_e_sph_eq_kpc','log<Sigma>_e','GJC23log(M*,gal/M_sun)','GJC23log(sSFR)'
           ,'D_L']
df_test=df_ell[test_keys]
df_test=df_ell[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_distance.csv',index=False)

df_test=df_len[test_keys]
df_test=df_len[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len_distance.csv',index=False)

df_test=df_spr[test_keys]
df_test=df_spr[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr_distance.csv',index=False)
# Out:
# 35
# 38
# 28

# %%
# test data sampling code
df=pd.read_csv('R_e_data/causal_BH_ell_std.csv')
keys=['M_BH','log_sigma0','log_R_e_sph_eq_kpc','log<Sigma>_e','GJC23log(M*,gal/M_sun)','GJC23log(sSFR)','GJC23W2-W3']
std_keys=['M_BH_std_sym','log_sigma0_std','log_R_e_sph_eq_kpc_std','log<Sigma>_e_std','GJC23log(M*,gal/M_sun)_std','GJC23log(sSFR)_std','GJC23W2-W3_std']

# sample the data according to the std

df_sampled=pd.DataFrame()
for key,std_key in zip(keys,std_keys):
    df_sampled[key]=df[key]+np.random.randn(len(df))*df[std_key]
df_sampled
# Out:
#          M_BH  log_sigma0  log_R_e_sph_eq_kpc  log<Sigma>_e  \
# 0    9.619389    2.488769            1.046234      2.858411
# 1    9.025697    2.507996            1.311729      3.060324
# 2    7.524382    2.286745            0.544149      2.915897
# 3    8.298238    2.372967            1.601938      2.383221
# 4    8.583541    2.532013            0.904297      3.043061
# 5    9.707115    2.425027            0.971948      3.061367
# 6   10.271868    2.509320            1.043916      2.719534
# 7    9.618033    2.500998            1.255337      2.893790
# 8    8.172480    2.142827            0.352629      2.827513
# 9    8.870851    2.306185            0.375089      3.196431
# 10   8.409128    2.358752            0.593174      3.126252
# 11   8.194020    2.334440            1.200005      2.607152
# 12   8.358609    2.348825            0.901419      3.006383
# 13   8.698421    2.285001            0.385606      2.715037
# 14   9.944881    2.490261            1.521660      2.049005
# 15   9.555761    2.396077            0.917633      2.675539
# 16   9.087720    2.474371            0.741361      2.935455
# 17   9.115245    2.450894            0.500441      3.577602
# 18   8.978113    2.441266            1.371342      2.656687
# 19   9.341199    2.440834            0.959765      2.869180
# 20   7.996854    2.244619            0.842858      3.019836
# 21   9.848639    2.511357            0.694544      3.063942
# 22   8.619235    2.400879            0.691574      2.442012
# 23   8.552812    2.360366            0.736819      2.448406
# 24   9.865200    2.514790            0.700237      3.085101
# 25   8.108163    2.220329            1.459467      2.001659
# 26  10.411555    2.593210            1.374255      2.417232
# 27   9.071312    2.384928            0.532253      2.903120
# 28   9.768736    2.526749            1.011230      3.031989
# 29   8.416365    2.286079            0.768158      2.409446
# 30   9.057710    2.361347            1.051463      2.572616
# 31   8.726526    2.543281            1.031010      2.811817
# 32   9.318942    2.471414            0.783172      3.006142
# 33   9.496973    2.505763            1.034594      2.530273
# 34   9.024190    2.422540            1.088512      2.357208
#
#     GJC23log(M*,gal/M_sun)  GJC23log(sSFR)  GJC23W2-W3
# 0                11.154437      -11.760427    0.393057
# 1                11.378566      -12.382764   -0.048021
# 2                10.659568      -11.545542    0.363058
# 3                11.489231       -9.810824    2.978797
# 4                11.107195      -12.758374    0.136806
# 5                11.362335      -15.524125    0.010223
# 6                11.614510      -14.664461   -0.243165
# 7                11.221369      -15.316395   -0.324199
# 8                10.205788      -14.318697    0.058478
# 9                10.632182      -15.004219    0.097201
# 10               10.656349      -12.134350    0.604251
# 11               11.003682      -13.000804    0.128120
# 12               11.180241      -11.524968    0.733313
# 13               10.671244      -15.227830   -0.148270
# 14               11.518226      -13.826763   -0.403820
# 15               11.341379      -15.350998   -0.032194
# 16               11.243531      -11.869065    0.318369
# 17               10.505266      -14.784285   -0.015887
# 18               11.125868      -15.335151    0.031320
# 19               11.534563      -12.089399    0.374249
# 20               10.503077      -11.914176    0.177522
# 21               11.233793      -11.948376    0.273189
# 22               10.481753      -12.132214    0.570828
# 23               11.017221      -11.905853    0.425672
# 24               11.196966      -12.048181    0.537819
# 25               10.622834      -12.120253    0.137298
# 26               11.672479      -15.115171   -0.251800
# 27               10.955077      -11.934011    0.266754
# 28               11.597428      -12.407197   -0.022568
# 29               10.810882      -14.989981   -0.166868
# 30               11.255615      -15.307449   -0.038712
# 31               11.503703      -11.682259    1.008918
# 32               11.302060      -11.843840    0.717349
# 33               11.493167      -15.823036    0.153353
# 34               11.364661      -14.335858   -0.389733

# %%
# test LOO data sampling code
df=pd.read_csv('R_e_data/causal_BH_ell.csv')

# Leave one out sampling by removing one galaxy at a time
for i in range(len(df)):
    df_sampled=df.drop(i)

df_sampled
# Out:
#          M_BH  log_sigma0  log_R_e_sph_eq_kpc  log<Sigma>_e  \
# 0    9.380211    2.471453            0.885259      2.889338
# 1    9.102971    2.515012            0.960195      2.871399
# 2    7.591065    2.296073            0.538083      2.906781
# 3    8.903090    2.388510            1.239710      2.507699
# 4    8.667597    2.521439            0.756180      3.010215
# 5    9.649324    2.424277            0.798621      3.029951
# 6   10.279788    2.520405            1.221646      2.660104
# 7    9.614930    2.492718            1.150179      2.611212
# 8    8.243991    2.133858            0.361426      2.767968
# 9    8.626649    2.306361            0.430994      3.188065
# 10   8.376651    2.375755            0.474726      3.067010
# 11   8.486884    2.330819            0.904716      2.673498
# 12   8.165530    2.346725            0.895423      2.743881
# 13   8.632972    2.288339            0.662796      2.752287
# 14   9.935785    2.488635            1.476472      2.028310
# 15   9.473662    2.390140            0.921722      2.798623
# 16   9.205903    2.472361            0.836229      2.885614
# 17   8.967248    2.466363            0.270306      3.354656
# 18   8.949363    2.443404            1.042694      2.592638
# 19   9.359829    2.450218            1.006359      2.812340
# 20   7.948528    2.251784            0.430349      2.963663
# 21   9.853090    2.509203            0.848503      3.051074
# 22   8.669202    2.398478            0.705564      2.675096
# 23   8.586157    2.357535            0.883093      2.581034
# 24   9.670439    2.519171            0.798376      3.040975
# 25   8.096544    2.218063            1.086360      2.029802
# 26  10.292166    2.594437            1.433238      2.376167
# 27   8.854218    2.400365            0.638190      3.156957
# 28   9.863471    2.536987            1.014084      2.871554
# 29   8.198834    2.261477            0.764729      2.521646
# 30   9.037789    2.375133            0.981864      2.641141
# 31   8.772377    2.494600            1.161614      2.659333
# 32   9.348897    2.445495            0.765791      3.040660
# 33   9.354519    2.501196            1.107820      2.521715
#
#     GJC23log(M*,gal/M_sun)  GJC23log(sSFR)  GJC23W2-W3
# 0                    11.24      -12.003463        0.39
# 1                    11.47      -12.472614        0.02
# 2                    10.64      -11.647889        0.27
# 3                    11.52       -9.806383        3.00
# 4                    11.23      -12.723495        0.17
# 5                    11.39      -15.691030        0.07
# 6                    11.71      -15.232879       -0.34
# 7                    11.39      -15.088970       -0.21
# 8                    10.13      -14.431030       -0.09
# 9                    10.64      -14.941030        0.12
# 10                   10.63      -12.049075        0.50
# 11                   11.03      -13.160768        0.06
# 12                   11.13      -11.729635        0.73
# 13                   10.56      -14.861030       -0.13
# 14                   11.45      -14.796787       -0.43
# 15                   11.30      -15.601030       -0.03
# 16                   11.17      -11.985309        0.22
# 17                   10.47      -14.771030        0.00
# 18                   11.14      -15.441030       -0.04
# 19                   11.41      -12.079586        0.28
# 20                   10.53      -12.048557        0.15
# 21                   11.31      -12.019965        0.33
# 22                   10.77      -12.118722        0.50
# 23                   10.89      -11.819593        0.42
# 24                   11.24      -12.022779        0.42
# 25                   10.65      -12.109671        0.09
# 26                   11.72      -15.021030       -0.17
# 27                   11.02      -11.936139        0.22
# 28                   11.64      -12.467397        0.04
# 29                   10.70      -15.001030       -0.23
# 30                   11.18      -15.481030       -0.13
# 31                   11.51      -11.492299        1.05
# 32                   11.22      -11.690313        0.58
# 33                   11.29      -15.113909       -0.01
