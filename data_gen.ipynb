# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import seaborn as sns

# %%
df_full = pd.read_csv('SMBH_Data_03_06_24.csv',header=1)

df_ell=df_full[(df_full['ETG']==1)&(df_full['Disk']==0)]

df_len=df_full[(df_full['ETG']==1)&(df_full['Disk']==1)]

df_spr=df_full[(df_full['ETG']==0)&(df_full['Disk']==1)]


len(df_ell),len(df_len),len(df_spr),len(df_full)
# Out:
# (45, 50, 49, 145)

# %%
# show all columns in df_full, without truncation
for col in df_full.columns:
    print(col)
# Out:
# ID
# Galaxy
# ra
# dec
# RA_deg
# DEC_deg
# Morphology
# Type
# ETG
# Leda Type
# T-type
# T-type_std
# Arm Class
# Bar
# Disk
# Ring
# Core
# Multiple
# Compactness
# AGN
# Pseudobulge
# BCG
# cD
# M_BH
# M_BH_std_+
# M_BH_std_-
# M_BH_std_sym
# M*_sph
# M*_sph_std
# M*_disk
# M*_disk_std
# M*_gal
# M*_gal_std
# B/T
# B/T_std
# log_B/T
# log_B/T_std
# D/T
# D/T_std
# log_D/T
# log_D/T_std
# m_#_of_arms
# phi
# phi_std
# tan_phi
# tan_phi_std
# sigma0
# sigma0_std
# log_sigma0
# log_sigma0_std
# v_max
# v_max_std
# log_v_max
# log_v_max_std
# M_DM
# M_DM_std
# M_BH/M*_sph
# M_BH/M*_sph_std
# log_M_BH/M*_sph
# log_M_BH/M*_sph_std
# M_BH/M*_disk
# M_BH/M*_disk_std
# log_M_BH/M*_disk
# log_M_BH/M*_disk_std
# M_BH/M*_gal
# M_BH/M*_gal_std
# log_M_BH/M*_gal
# log_M_BH/M*_gal_std
# R_e_sph_maj
# R_e_sph_maj_std
# log_R_e_sph_maj
# log_R_e_sph_maj_std
# R_e_sph_eq_kpc
# R_e_sph_eq_kpc_std
# log_R_e_sph_eq_kpc
# log_R_e_sph_eq_kpc_std
# n_sph_maj
# n_sph_maj_std
# log_n_sph_maj
# ...

# %%
test_keys=['Galaxy','M_BH','M_BH_std_sym', 'log_sigma0','log_sigma0_std','log_R_e_sph_eq_kpc','log_R_e_sph_eq_kpc_std',
           'log<Sigma>_e','log<Sigma>_e_std','GJC23log(M*,gal/M_sun)','GJC23log(M*,gal/M_sun)_std','GJC23log(sSFR)','GJC23log(sSFR)_std',
           'GJC23W2-W3','GJC23W2-W3_std']
df_ell=df_ell[test_keys]
df_len=df_len[test_keys]
df_spr=df_spr[test_keys]

df_test=df_ell[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_std_withname.csv',index=False)
# drop the galaxy name
df_test=df_ell[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_std.csv',index=False)

df_test=df_len[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len_std_withname.csv',index=False)
# drop the galaxy name
df_test=df_len[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len_std.csv',index=False)

df_test=df_spr[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr_std_withname.csv',index=False)
# drop the galaxy name
df_test=df_spr[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr_std.csv',index=False)
# Out:
# 35
# 35
# 38
# 38
# 28
# 28

# %%
test_keys=['Galaxy','M_BH', 'log_sigma0','log_R_e_sph_eq_kpc','log<Sigma>_e','GJC23log(M*,gal/M_sun)','GJC23log(sSFR)'
           ,'GJC23W2-W3']
df_test=df_ell[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_withname.csv',index=False)
# drop the galaxy name
df_test=df_ell[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell.csv',index=False)

df_test=df_len[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len_withname.csv',index=False)
# drop the galaxy name
df_test=df_len[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len.csv',index=False)

df_test=df_spr[test_keys]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr_withname.csv',index=False)
# drop the galaxy name
df_test=df_spr[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr.csv',index=False)
# Out:
# 35
# 35
# 38
# 38
# 28
# 28

# %%
test_keys=['Galaxy','M_BH', 'log_sigma0','log_R_e_sph_eq_kpc','GJC23log(M*,gal/M_sun)','GJC23log(sSFR)']

# df_test=df_ell[test_keys]
# df_test=df_test.dropna()
# print(len(df_test))
# df_test.to_csv('R_e_data/causal_BH_ell_withname.csv',index=False)
# drop the galaxy name
df_test=df_ell[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_5var.csv',index=False)

# df_test=df_len[test_keys]
# df_test=df_test.dropna()
# print(len(df_test))
# df_test.to_csv('R_e_data/causal_BH_len_withname.csv',index=False)
# # drop the galaxy name
# df_test=df_len[test_keys[1:]]
# df_test=df_test.dropna()
# print(len(df_test))
# df_test.to_csv('R_e_data/causal_BH_len.csv',index=False)

# df_test=df_spr[test_keys]
# df_test=df_test.dropna()
# print(len(df_test))
# df_test.to_csv('R_e_data/causal_BH_spr_withname.csv',index=False)
# # drop the galaxy name
# df_test=df_spr[test_keys[1:]]
# df_test=df_test.dropna()
# print(len(df_test))
# df_test.to_csv('R_e_data/causal_BH_spr.csv',index=False)
# Out:
# 35

# %%
test_keys=['Galaxy','M_BH', 'log_sigma0','log_R_e_sph_eq_kpc','log<Sigma>_e','GJC23log(M*,gal/M_sun)','GJC23log(sSFR)']

# df_test=df_ell[test_keys]
# df_test=df_test.dropna()
# print(len(df_test))
# df_test.to_csv('R_e_data/causal_BH_ell_withname.csv',index=False)
# drop the galaxy name
df_test=df_ell[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_ell_6var.csv',index=False)

# df_test=df_len[test_keys]
# df_test=df_test.dropna()
# print(len(df_test))
# df_test.to_csv('R_e_data/causal_BH_len_withname.csv',index=False)
# drop the galaxy name
df_test=df_len[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_len_6var.csv',index=False)

# df_test=df_spr[test_keys]
# df_test=df_test.dropna()
# print(len(df_test))
# df_test.to_csv('R_e_data/causal_BH_spr_withname.csv',index=False)
# drop the galaxy name
df_test=df_spr[test_keys[1:]]
df_test=df_test.dropna()
print(len(df_test))
df_test.to_csv('R_e_data/causal_BH_spr_6var.csv',index=False)
# Out:
# 35
# 38
# 28
